# %% [markdown]
# <a href="https://colab.research.google.com/github/Mendietazo/Diplomado-Ciencia-de-Datos-2024/blob/main/Omar-Entregas-/Data_Analyst_Assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Data Analyst Assignment

# %%
# YOUR CODE HERE:
import pandas as pd
from google.colab import drive

drive.mount('/content/drive')
# %cd /content/drive/ My \Drive/Diplomado
employee_df = pd.read_excel('Assignment_2.xlsx', sheet_name = "Employee_Data")
trainings_df = pd.read_excel('Assignment_2.xlsx', sheet_name = "Completed_Trainings")
performance_df = pd.read_excel('Assignment_2.xlsx', sheet_name = "Performance Data")
# Out:
# Mounted at /content/drive
# /content/drive/ My Drive/Diplomado

# %% [markdown]
# ## Data Challenge
#
# Sales leadership has tasked you with analyzing the data to discover how employee training
# impacts sales performance and effectiveness. The goal is to identify patterns and provide
# actionable recommendations that drive sales growth and improve team performance by
# answering the following questions.
# Questions
# 1. What is the training completion rate for each course by segments (SVP Leader/Region),
# factoring in the following caveats? Training is required for all employees except:
# * Employees currently on leave are exempt from the training requirement.
# * 'Sell More Suite SKU' course is not required for employees within the 'Advocacy'
# cost center family.
# * “Suite/Automation Technical Lab” and “Advanced Suite Bots Lab Course”
# courses are required only for employees in the 'PreSales' and 'Services' cost
# center family.
#
# 2. How would you analyze the performance of an account executive? Is there a difference
# between those who have completed training and those who have not? How would you
# segment the data and present your findings to senior stakeholders?
# * Hint: Look at this from an overall employee perspective who has completed any
# training vs. those who have not completed any training. Any training would count,
#
# rather than distinguishing which specific courses were completed, as they all
# contribute to one Suite product.
#
# 3. Any other interesting insights that you can see in the data? Any data quality issues with
# the data? Any challenges with analyzing the data? What additional data do you think
# would be useful for further analyzing the existing datasets?
#
#
#
# ---

# %% [markdown]
# ## Data Dictionary
#
# ### Table 1 : Employee Information
#
# This table maintains critical employment details for organization members, including
# identification, job titles, management hierarchies, tenure, and work region
#
# * **Employee_ID:** Unique identifier for each employee.
# * **SVP Leader:** Leader overseeing the employee.
# * **Business Title:** Official job title of the employee.
# * **Cost Center:** Identifier for the employee's department or unit for cost tracking.
# * **Cost Center Family:** Group of related cost centers for financial reporting.
# * **Length of Service:** Total time the employee has worked at the company.
# * **Leave Status:** Indication of whether the employee is on leave.
# * **Is People Manager?:** Indicates if the employee oversees other staff.
# * **Region:** Geographic area where the employee works.
# * **Manager IC Helper:** Additional data supporting managerial status.
# * **IC:** Individual Contributor
#
# ### Table 2: Completed Trainings
# This table records the professional development activities of employees by linking completed
# training programs to their unique identifiers
# * **Employee_ID:** Unique identifier linked to an employee who completed the training.
# * **Training Name:** Name of the training program or course that the employee completed.
#
# ### Table 3: Performance Data
# This table includes the sales and revenue generation activities of employees by cataloguing
# opportunities, their progression, and financial outcomes. It captures granular data on sales
# stage milestones, product-related charges, and revenue figures, all linked by employee and
# opportunity identifiers, making it a vital asset for analyzing sales performance and compensation
# metrics.
#
# * **Employee_ID:** Unique identifier for the employee associated.
# * **Opportunity ID:** Unique identifier for the sales opportunity.
# * **Type:** The category or classification of the opportunity.
# * Expansion is for existing business
#
# * **Stage 2+ Date:** The date when the opportunity reached or surpassed stage 2 in the
# sales process.
# * **Stage:** Current stage of the opportunity in the sales pipeline.
#  * 02 - Discovery: Initial stage where potential needs and opportunities are
# identified with the client.
#  * 03 - Solution Review: Potential solutions are presented and reviewed with the
# client.
#  * 04 - Solution Validation: Client feedback is incorporated, and solutions are
# refined and validated.
#  * 05 - Contracting / Verba: Terms are negotiated and a verbal agreement may be
# reached.
#  * 06 - Signed/07 - Closed: Formal agreement is executed with signatures from all
# parties. Signed and Closed are counted as finalized
# * **Close Date:** The date when the opportunity was closed.
# * **Product Rate Plan Charge:** The charge associated with the product's rate plan.
# * **Product Name:** The name of the product related to the opportunity.
# * **Add-On ARR (converted):** The value of the additional ARR from add-ons,
# * **Total Commissionable ARR (converted):** The total annual recurring revenue that is
# eligible for commission

# %% [markdown]
# # Respuestas
# ## 1. Training completion rate for each course by segments (SVP Leader/Region)
#
# *   Filter 'On Leave' in Live Status Column
# *   Filter 'Advocacy' cost center family column, 'Sell More Suite SKU' will not be taken into account
# *   “Suite/Automation Technical Lab” and “Advanced Suite Bots Lab Course” courses are required only for employees in the 'PreSales' and 'Services' cost center family.

# %%
#Unimos 2 tablas con merge left
df1 = employee_df.merge(trainings_df, on = ['Employee_ID'], how = 'left')

# %%
#Los empleados 'On Leave' no están obligados a tomar curso alguno, entonces los quitamos de la base de datos
#df1 = df1[df1['Leave Status'] != 'On Leave']
#Si un empleado con cost center family advocacy hace el curso "Sell More Suite SKU" no debe ser tomado en cuenta

df1[df1['Cost Center Family'] != 'Advocacy' & df1['Training_Completed']!= 'Sell More Suite SKU']
# Out:
#       Employee_ID SVP Leader                          Business Title  \
# 0               1   Leader 1     Senior Commercial Account Executive
# 1               2   Leader 1     Senior Commercial Account Executive
# 2               3   Leader 1     Senior Commercial Account Executive
# 3               4   Leader 2  Enterprise Corporate Account Executive
# 4               5   Leader 1     Senior Commercial Account Executive
# ...           ...        ...                                     ...
# 3122         2528   Leader 5                       Contingent Worker
# 3123         2529   Leader 5                       Contingent Worker
# 3124         2530   Leader 5                       Contingent Worker
# 3125         2531   Leader 5                       Contingent Worker
# 3126         2532   Leader 5                       Contingent Worker
#
#                   Cost Center Cost Center Family  Length of service  \
# 0           532 Commercial AE         Commercial                 20
# 1           532 Commercial AE         Commercial                 13
# 2           552 Mid-Market AE         Mid-Market                 44
# 3     508 LATAM Enterprise AE         Enterprise                  9
# 4           532 Commercial AE         Commercial                 15
# ...                       ...                ...                ...
# 3122    256 Prof Services Ops           Services                  0
# 3123    256 Prof Services Ops           Services                  0
# 3124    256 Prof Services Ops           Services                  0
# 3125    256 Prof Services Ops           Services                  0
# 3126    256 Prof Services Ops           Services                  0
#
#      Leave Status  is People Manager? Region Manager IC Helper  \
# 0          Active               False   EMEA                IC
# 1          Active               False   EMEA                IC
# 2          Active               False   EMEA                IC
# 3          Active               False  LATAM                IC
# 4          Active               False   EMEA                IC
# ...           ...                 ...    ...               ...
# 3122       Active               False   EMEA                IC
# 3123       Active               False   EMEA                IC
# 3124       Active               False   EMEA                IC
# 3125       Active               False   EMEA                IC
# 3126       Active               False   EMEA                IC
#
#                   Training_Completed
# 0     Suite/Automation Technical Lab
# 1                Sell More Suite SKU
# 2                                NaN
# 3                                NaN
# 4                Sell More Suite SKU
# ...                              ...
# 3122                             NaN
# 3123                             NaN
# 3124                             NaN
# 3125                             NaN
# 3126                             NaN
#
# [3013 rows x 11 columns]

# %%
Training_Percentage = df1.value_counts(['SVP Leader','Region'], normalize = True)*100
Training_Percentage = Training_Percentage.reset_index()
Training_Percentage
# Out:
#    SVP Leader         Region          0
# 0    Leader 5  North America  16.853214
# 1    Leader 5           APAC  12.184202
# 2    Leader 5           EMEA  10.265430
# 3    Leader 9  North America   7.451231
# 4    Leader 4  North America   5.244643
# 5    Leader 1           EMEA   5.116725
# 6    Leader 9           EMEA   4.732971
# 7   Leader 10  North America   3.869524
# 8    Leader 3  North America   3.741605
# 9    Leader 5          LATAM   3.293892
# 10   Leader 3           EMEA   3.261912
# 11  Leader 10           EMEA   2.782219
# 12  Leader 11  North America   2.398465
# 13   Leader 9           APAC   1.822833
# 14  Leader 10          LATAM   1.726895
# 15   Leader 2          LATAM   1.630956
# 16   Leader 9          LATAM   1.407099
# 17  Leader 10           APAC   1.407099
# 18  Leader 14           APAC   1.247202
# 19   Leader 3           APAC   1.215222
# 20   Leader 8  North America   1.087304
# 21   Leader 7  North America   1.087304
# 22   Leader 1           APAC   0.991366
# 23   Leader 3          LATAM   0.959386
# 24  Leader 12           EMEA   0.703550
# 25   Leader 2  North America   0.511673
# 26   Leader 8           APAC   0.479693
# 27  Leader 12  North America   0.479693
# 28  Leader 13           APAC   0.383754
# 29   Leader 8           EMEA   0.351775
# 30  Leader 12           APAC   0.319795
# 31   Leader 7           EMEA   0.255836
# 32  Leader 12          LATAM   0.223857
# 33   Leader 6  North America   0.159898
# 34   Leader 7           APAC   0.095939
# 35   Leader 6          LATAM   0.063959
# 36   Leader 2           EMEA   0.063959
# 37   Leader 2           APAC   0.063959
# 38   Leader 6           APAC   0.031980
# 39   Leader 7          LATAM   0.031980

# %%
df1.Training_Completed.unique()
# Out:
# array(['Suite/Automation Technical Lab', 'Sell More Suite SKU', nan,
#        'Advanced Suite Bots Lab Course'], dtype=object)

# %%
df1.head()
# Out:
#    Employee_ID SVP Leader                          Business Title  \
# 0            1   Leader 1     Senior Commercial Account Executive
# 1            2   Leader 1     Senior Commercial Account Executive
# 2            3   Leader 1     Senior Commercial Account Executive
# 3            4   Leader 2  Enterprise Corporate Account Executive
# 4            5   Leader 1     Senior Commercial Account Executive
#
#                Cost Center Cost Center Family  Length of service Leave Status  \
# 0        532 Commercial AE         Commercial                 20       Active
# 1        532 Commercial AE         Commercial                 13       Active
# 2        552 Mid-Market AE         Mid-Market                 44       Active
# 3  508 LATAM Enterprise AE         Enterprise                  9       Active
# 4        532 Commercial AE         Commercial                 15       Active
#
#    is People Manager? Region Manager IC Helper              Training_Completed
# 0               False   EMEA                IC  Suite/Automation Technical Lab
# 1               False   EMEA                IC             Sell More Suite SKU
# 2               False   EMEA                IC                             NaN
# 3               False  LATAM                IC                             NaN
# 4               False   EMEA                IC             Sell More Suite SKU

# %%
set(df1['Cost Center Family'].unique())
# Out:
# {'Advocacy',
#  'Commercial',
#  'Enterprise',
#  'Mid-Market',
#  'Ops/Strat/Eff',
#  'Partners',
#  'PreSales',
#  'Renewals',
#  'SMB',
#  'Sales Management',
#  'Services',
#  'Success',
#  'Transformational',
#  'XDR'}

# %%
total_employees.columns
# Out:
# Index(['SVP Leader', 'Region', 'Count'], dtype='object')

# %% [markdown]
# How would you analyze the performance of an account executive? Is there a difference between those who have completed training and those who have not? How would you segment the data and present your findings to senior stakeholders?
# Hint: Look at this from an overall employee perspective who has completed any training vs. those who have not completed any training. Any training would count,
# rather than distinguishing which specific courses were completed, as they all contribute to one Suite product.

# %%
Employee_with_course = trainings_df.Employee_ID.unique()
Employee_with_course = pd.DataFrame(Employee_with_course).rename(columns= {0:'Employee_ID'})
Employee_with_course['MadeCourse'] = 'yes'

# %%
Performance_and_Course = performance_df.merge(Employee_with_course, on = ['Employee_ID'], how = 'left')

# %%
Yes_Course = Performance_and_Course[Performance_and_Course['MadeCourse'] == 'yes']
Yes_Course.head()
# Out:
#    Employee_ID  Opportunity ID          Type Stage 2+ Date           Stage  \
# 1        435.0           10005     Expansion    2017-12-14  02 - Discovery
# 3       1634.0           10015     Expansion    2017-12-15  02 - Discovery
# 4       1998.0           10020  New Business    2017-12-22  02 - Discovery
# 5       1561.0           10025     Expansion    2017-12-15  02 - Discovery
# 8        243.0           10040     Expansion    2017-12-15  02 - Discovery
#
#   Close Date Product Rate Plan Charge     Product Name  \
# 1 2018-03-02       Suite Subscription  Support: Addons
# 3 2018-03-30       Suite Subscription  Support: Addons
# 4 2018-02-13       Suite Subscription  Support: Addons
# 5 2018-06-09       Suite Subscription  Support: Addons
# 8 2018-06-29       Suite Subscription            Suite
#
#   Add-On ARR (converted) Currency  Add-On ARR (converted)  \
# 1                             USD                    6861
# 3                             USD                   47413
# 4                             USD                    3973
# 5                             USD                   50056
# 8                             USD                   18982
#
#   Total Commissionable ARR (converted) Currency  \
# 1                                           USD
# 3                                           USD
# 4                                           USD
# 5                                           USD
# 8                                           USD
#
#    Total Commissionable ARR (converted) MadeCourse
# 1                                  4561        yes
# 3                                 46811        yes
# 4                                  6700        yes
# 5                                 28910        yes
# 8                                 63980        yes

# %%
No_Course = Performance_and_Course[Performance_and_Course['MadeCourse'].isna()]
No_Course.head()
# Out:
#     Employee_ID  Opportunity ID          Type Stage 2+ Date  \
# 0         963.0           10000  New Business    2016-10-16
# 2          33.0           10010     Expansion    2017-12-17
# 6        1389.0           10030     Expansion    2017-12-15
# 7        1513.0           10035     Expansion    2017-12-15
# 14       1348.0           10070     Expansion    2017-12-15
#
#                        Stage Close Date Product Rate Plan Charge  \
# 0       03 - Solution Review 2018-06-03       Suite Subscription
# 2             02 - Discovery 2018-06-09       Suite Subscription
# 6       03 - Solution Review 2018-04-09       Suite Subscription
# 7   04 - Solution Validation 2018-01-19       Suite Subscription
# 14            02 - Discovery 2018-04-08       Suite Subscription
#
#        Product Name Add-On ARR (converted) Currency  Add-On ARR (converted)  \
# 0   Support: Addons                             USD                   25771
# 2   Support: Addons                             USD                   21198
# 6   Support: Addons                             USD                  226204
# 7             Suite                             USD                   29000
# 14  Support: Addons                             USD                   83083
#
#    Total Commissionable ARR (converted) Currency  \
# 0                                            USD
# 2                                            USD
# 6                                            USD
# 7                                            USD
# 14                                           USD
#
#     Total Commissionable ARR (converted) MadeCourse
# 0                                 225073        NaN
# 2                                  11215        NaN
# 6                                 330811        NaN
# 7                                  25562        NaN
# 14                                193143        NaN

# %%
print("Este porcentge de personas hizo el curso y lograron firmar el contrato")
print(sum(Yes_Course.Stage=='06 - Signed')/len(Yes_Course)*100,"%")
# Out:
# Este porcentge de personas hizo el curso y lograron firmar el contrato
# 14.076246334310852 %

# %%
print("Este porcentge de personas hizo el curso y lograron firmar el contrato")
print(sum(No_Course.Stage=='06 - Signed')/len(No_Course)*100,"%")
# Out:
# Este porcentge de personas hizo el curso y lograron firmar el contrato
# 13.533834586466165 %

# %%
print("Se mejoró la productividad en medio punto porsentual")
# Out:
# Se mejoró la productividad en medio punto porsentual
